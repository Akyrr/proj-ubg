# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('glass.csv')

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64
# 1

# %%
df = df.drop_duplicates(keep='first')

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.boxplot(df)
plt.show()

# %%
cols = [1,5,6,7]
col = df.columns[cols]
Q1 = df.iloc[col].quantile(0.25)
Q3 = df.iloc[col].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df[col] >= lower) & (df[col] <= upper)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 3
#       1 cols = [1,5,6,7]
#       2 col = df.columns[cols]
# ----> 3 Q1 = df.iloc[col].quantile(0.25)
#       4 Q3 = df.iloc[col].quantile(0.75)
#       5 IQR = Q3 - Q1
#
# File ~/Documents/Akyr/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Documents/Akyr/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1744, in _iLocIndexer._getitem_axis(self, key, axis)
#    1742 # a list of integers
#    1743 elif is_list_like_indexer(key):
# -> 1744     return self._get_list_axis(key, axis=axis)
#    1746 # a single integer
#    1747 else:
#    1748     key = item_from_zerodim(key)
#
# File ~/Documents/Akyr/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1715, in _iLocIndexer._get_list_axis(self, key, axis)
#    1698 """
#    1699 Return Series values by list or array of integers.
#    1700
#    (...)   1712 `axis` can only be zero.
#    1713 """
#    1714 try:
# -> 1715     return self.obj._take_with_is_copy(key, axis=axis)
#    1716 except IndexError as err:
#    1717     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#    1718     raise IndexError("positional indexers are out-of-bounds") from err
#
# File ~/Documents/Akyr/.venv/lib/python3.13/site-packages/pandas/core/generic.py:4175, in NDFrame._take_with_is_copy(self, indices, axis)
#    4164 @final
#    4165 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4166     """
#    4167     Internal version of the `take` method that sets the `_is_copy`
#    4168     attribute to keep track of the parent dataframe (using in indexing
#    (...)   4173     See the docstring of `take` for full explanation of the parameters.
#    4174     """
# -> 4175     result = self.take(indices=indices, axis=axis)
#    4176     # Maybe set copy if we didn't actually change the index.
#    4177     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/Documents/Akyr/.venv/lib/python3.13/site-packages/pandas/core/generic.py:4128, in NDFrame.take(self, indices, axis, **kwargs)
#    4125 nv.validate_take((), kwargs)
#    4127 if not isinstance(indices, slice):
# -> 4128     indices = np.asarray(indices, dtype=np.intp)
#    4129     if (
#    4130         axis == 0
#    4131         and indices.ndim == 1
#    4132         and using_copy_on_write()
#    4133         and is_range_indexer(indices, len(self))
#    4134     ):
#    4135         return self.copy(deep=None)
#
# File ~/Documents/Akyr/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:924, in Index.__array__(self, dtype, copy)
#     919 """
#     920 The array interface, return my values.
#     921 """
#     922 if copy is None:
#     923     # Note, that the if branch exists for NumPy 1.x support
# --> 924     return np.asarray(self._data, dtype=dtype)
#     926 return np.array(self._data, dtype=dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Na'

# %%
df['Si'] = (df['Si'] - df['Si'].median()) / IQR

# %%
# standarisasi method
# df['Si'] = df['Si'] - df['Si'].mean() / df['Si'].std()

# %%
df['Ca'].unique
# Out:
# <bound method Series.unique of 0      8.75
# 1      7.83
# 2      7.78
# 3      8.22
# 4      8.07
#        ...
# 209    9.18
# 210    8.40
# 211    8.44
# 212    8.48
# 213    8.62
# Name: Ca, Length: 213, dtype: float64>
