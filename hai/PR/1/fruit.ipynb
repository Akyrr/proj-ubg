# %% [markdown]
# # **Fruit Dataset**

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# ### 1.1 Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import math
from collections import Counter

# %% [markdown]
# ### 1.2 Load Dataset

# %%
df = pd.read_csv('fruit.csv')

# %% [markdown]
# ### 1.3 Baca Dataset

# %%
# 5 Baris pertama
df.head()
# Out:
#    Acidity  Firmness  Sweetness  Weight  Water_Content Fruit_Name  \
# 0     3.74      3.14       6.94  173.40          84.92      Apple
# 1     4.37      2.79       6.10  165.28          88.98     Orange
# 2     4.09      2.80       6.74  183.04          74.89     Orange
# 3     4.60      2.76       6.57  192.92          71.71      Apple
# 4     1.87      4.64       7.84  185.15          72.72      Apple
#
#    Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# 0             1.19                3.20           2.02
# 1             1.57                1.73           1.84
# 2             1.46                2.65           2.41
# 3             1.67                1.97           2.65
# 4             0.40                5.97           2.51

# %%
# 10 baris acak 
df.sample(10)
# Out:
#      Acidity  Firmness  Sweetness  Weight  Water_Content Fruit_Name  \
# 893     2.88      4.25       6.87  218.48          81.23      Apple
# 126     2.99      3.32       8.07  168.91          78.85     Orange
# 151     3.37      4.57       6.95  206.52          82.51      Apple
# 315     5.00      1.99       7.15  153.23          91.24     Orange
# 563     4.55      3.99       8.55  182.84            NaN      Apple
# 406     3.74      3.46       6.61  209.63          77.99      Apple
# 188     4.48      3.17       7.64  173.26          76.22      Apple
# 559     2.60      2.96       8.43  144.64          71.22     Orange
# 889     2.84      2.92       9.28  159.90          71.70      Apple
# 602     3.05      4.23       7.95  166.59          63.05      Apple
#
#      Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# 893             0.68                3.99           2.66
# 126             0.90                 NaN           2.12
# ...

# %%
# Jumlah baris dan kolom
df.shape
# Out:
# (1220, 9)

# %%
# Ringkasan informasi
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Acidity             1211 non-null   float64
#  1   Firmness            1211 non-null   float64
#  2   Sweetness           1212 non-null   float64
#  3   Weight              1213 non-null   float64
#  4   Water_Content       1213 non-null   float64
#  5   Fruit_Name          1220 non-null   object
#  6   Acid_Firm_Ratio     1198 non-null   float64
#  7   Sweet_Acid_Balance  1198 non-null   float64
#  8   Density_Index       1206 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.9+ KB

# %%
# Ringkasan Statistik
df.describe()
# Out:
#            Acidity     Firmness    Sweetness       Weight  Water_Content  \
# count  1211.000000  1211.000000  1212.000000  1213.000000    1213.000000
# mean      3.444358     3.195186     7.208481   167.710511      78.832721
# std       0.948703     0.832227     1.317204    27.085074       9.053979
# min       0.650000     0.250000     3.390000    82.110000      48.910000
# 25%       2.790000     2.620000     6.340000   148.980000      72.510000
# 50%       3.420000     3.230000     7.195000   167.540000      78.830000
# 75%       4.065000     3.800000     8.080000   186.040000      84.960000
# max       7.260000     5.720000    11.290000   257.250000     110.550000
#
#        Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# count      1198.000000         1198.000000    1206.000000
# mean          1.230534            3.763180       2.134983
# std           0.925636            1.415305       0.456034
# min           0.200000           -0.920000       0.950000
# ...

# %% [markdown]
# ## 2. Data Cleaning

# %%
# Cek data duplikat
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
# Cek nilai kosong
df.isnull().sum()
# Out:
# Acidity                9
# Firmness               9
# Sweetness              8
# Weight                 7
# Water_Content          7
# Fruit_Name             0
# Acid_Firm_Ratio       22
# Sweet_Acid_Balance    22
# Density_Index         14
# dtype: int64

# %%
# cek total data kosong
df.isnull().sum().sum()
# Out:
# np.int64(98)

# %%
# Menghapus data duplikat
df = df.drop_duplicates(keep='first')

# %%
# Cek data duplikat
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Acidity               0
# Firmness              0
# Sweetness             0
# Weight                0
# Water_Content         0
# Fruit_Name            0
# Acid_Firm_Ratio       0
# Sweet_Acid_Balance    0
# Density_Index         0
# dtype: int64

# %%
df
# Out:
#       Acidity  Firmness  Sweetness  Weight  Water_Content Fruit_Name  \
# 0        3.74      3.14       6.94  173.40          84.92      Apple
# 1        4.37      2.79       6.10  165.28          88.98     Orange
# 2        4.09      2.80       6.74  183.04          74.89     Orange
# 3        4.60      2.76       6.57  192.92          71.71      Apple
# 4        1.87      4.64       7.84  185.15          72.72      Apple
# ...       ...       ...        ...     ...            ...        ...
# 1195     4.39      2.52       8.16  150.51          60.49     Orange
# 1196     4.78      2.34       7.86  156.76          88.12     Orange
# 1197     4.23      1.53       9.27  150.06          83.77     Orange
# 1198     3.89      0.74       9.12  139.35          96.12     Orange
# 1199     3.98      3.91       6.39  204.93          86.84      Apple
#
#       Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# 0                1.19                3.20           2.02
# ...

# %% [markdown]
# ## 3. Encoding

# %%
# Cek nilai unik target
df['Fruit_Name'].unique()
# Out:
# array(['Apple', 'Orange'], dtype=object)

# %%
# Encoding menggunakan mapping
df['Fruit_Name'] = df['Fruit_Name'].map({'Apple': 0, 'Orange': 1})

# %%
df.head()
# Out:
#    Acidity  Firmness  Sweetness  Weight  Water_Content  Fruit_Name  \
# 0     3.74      3.14       6.94  173.40          84.92           0
# 1     4.37      2.79       6.10  165.28          88.98           1
# 2     4.09      2.80       6.74  183.04          74.89           1
# 3     4.60      2.76       6.57  192.92          71.71           0
# 4     1.87      4.64       7.84  185.15          72.72           0
#
#    Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# 0             1.19                3.20           2.02
# 1             1.57                1.73           1.84
# 2             1.46                2.65           2.41
# 3             1.67                1.97           2.65
# 4             0.40                5.97           2.51

# %%
df['Fruit_Name'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: Fruit_Name, dtype: int64

# %%
df['Fruit_Name'].unique()
# Out:
# array([0, 1])

# %%
df
# Out:
#       Acidity  Firmness  Sweetness  Weight  Water_Content  Fruit_Name  \
# 0        3.74      3.14       6.94  173.40          84.92           0
# 1        4.37      2.79       6.10  165.28          88.98           1
# 2        4.09      2.80       6.74  183.04          74.89           1
# 3        4.60      2.76       6.57  192.92          71.71           0
# 4        1.87      4.64       7.84  185.15          72.72           0
# ...       ...       ...        ...     ...            ...         ...
# 1195     4.39      2.52       8.16  150.51          60.49           1
# 1196     4.78      2.34       7.86  156.76          88.12           1
# 1197     4.23      1.53       9.27  150.06          83.77           1
# 1198     3.89      0.74       9.12  139.35          96.12           1
# 1199     3.98      3.91       6.39  204.93          86.84           0
#
#       Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# 0                1.19                3.20           2.02
# ...

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Fruit_Name', data=df)
plt.title('Jumlah Target')
plt.xlabel('Target')
plt.ylabel('Nilai')
plt.show()

# %%
plt.pie(df['Fruit_Name'].value_counts(), labels=df['Fruit_Name'].value_counts().index, autopct='%1.1f%%')
plt.title('Presentase target')
plt.legend(['Apple', 'Orange'])
plt.show()

# %%
korelasi = df.corr()
sns.heatmap(korelasi, annot=True, cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Yang memiliki korelasi positif paling tinggi dengan target adalah 'Acidity', 'Acid_Firm_Ratio', dan 'Water_Content'. Sedangkan yang memiliki korelasi negatif paling tinggi adalah 'Destiny_Index', 'Firmness', dan 'Weight'

# %%
sns.histplot(df['Weight'])
plt.title('Hinsplot untuk Kolom Weight')
plt.show()

# %%
df['Weight'].median()
# Out:
# np.float64(167.37)

# %%
sns.histplot(df['Water_Content'])
plt.title('Hinsplot untuk Kolom Water_Content')
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=[5,5])
df.boxplot(column=['Weight', 'Water_Content'])
plt.show()

# %%
sns.scatterplot(df['Weight'])
plt.show()

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df
# Out:
#       Acidity  Firmness  Sweetness  Weight  Water_Content  Fruit_Name  \
# 0        3.74      3.14       6.94  173.40          84.92           0
# 1        4.37      2.79       6.10  165.28          88.98           1
# 2        4.09      2.80       6.74  183.04          74.89           1
# 3        4.60      2.76       6.57  192.92          71.71           0
# 4        1.87      4.64       7.84  185.15          72.72           0
# ...       ...       ...        ...     ...            ...         ...
# 1195     4.39      2.52       8.16  150.51          60.49           1
# 1196     4.78      2.34       7.86  156.76          88.12           1
# 1197     4.23      1.53       9.27  150.06          83.77           1
# 1198     3.89      0.74       9.12  139.35          96.12           1
# 1199     3.98      3.91       6.39  204.93          86.84           0
#
#       Acid_Firm_Ratio  Sweet_Acid_Balance  Density_Index
# 0                1.19                3.20           2.02
# ...

# %%
df.columns
# Out:
# Index(['Acidity', 'Firmness', 'Sweetness', 'Weight', 'Water_Content',
#        'Fruit_Name', 'Acid_Firm_Ratio', 'Sweet_Acid_Balance', 'Density_Index'],
#       dtype='object')

# %%
kolom = ['Weight', 'Water_Content', 'Acid_Firm_Ratio']

Q1 = df[kolom].quantile(0.25)
Q3 = df[kolom].quantile(0.75)

IQR = Q3 - Q1

batas_bawah = Q1 - 1.5 * IQR
batas_atas = Q3 + 1.5 * IQR

outlier = ((df[kolom] < batas_bawah) | (df[kolom] > batas_atas)).sum()

print(f"Batas atas = {batas_atas}")
print(f"\nBatas bawah = {batas_bawah}")           

print(f"\nNilai Outlier pada kolom Weight = {outlier}")

for col in kolom:
    median_col = df[col].median()
    mask = (df[col] < batas_bawah[col]) | (df[col] > batas_atas[col])
    df.loc[mask, col] = median_col
# Out:
# Batas atas = Weight             242.6600
# Water_Content      103.6625
# Acid_Firm_Ratio      2.5050
# dtype: float64
#
# Batas bawah = Weight             92.7400
# Water_Content      53.8025
# Acid_Firm_Ratio    -0.2550
# dtype: float64
#
# Nilai Outlier pada kolom Weight = Weight              5
# Water_Content      15
# Acid_Firm_Ratio    44
# dtype: int64

# %%
plt.figure(figsize=[5,5])
df.boxplot(column=['Weight', 'Water_Content', 'Acid_Firm_Ratio'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=[10,8])
#       2 df.boxplot(column=['Weight', 'Water_Content', 'Acid_Firm_Ratio'])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df['Acid_Firm_Ratio'].sort_values().tail(10)
# Out:
# 996    2.38
# 596    2.38
# 648    2.38
# 748    2.38
# 367    2.41
# 723    2.42
# 373    2.43
# 843    2.44
# 336    2.48
# 817    2.49
# Name: Acid_Firm_Ratio, dtype: float64

# %% [markdown]
# ## 4. Modeling

# %% [markdown]
# #### 4.1 Menentukan variabel Independent dan Dependent

# %%
X = df.drop('Fruit_Name', axis=1)
y = df['Fruit_Name']

# %% [markdown]
# #### 4.2 Split data Train dan Test menggunakan Stratified Data Split

# %%
idx_0 = np.where(y == 0)[0]
idx_1 = np.where(y == 1)[0]

random.shuffle(idx_0)
random.shuffle(idx_1)

train_0 = int(len(idx_0) * 0.8)
train_1 = int(len(idx_1) * 0.8)

train_idx = np.concatenate([idx_0[:train_0], idx_1[:train_1]])
test_idx = np.concatenate([idx_0[train_0:], idx_1[train_1:]])

X_train = X.iloc[train_idx].values 
X_test = X.iloc[test_idx].values 
y_train = y.iloc[train_idx].values 
y_test = y.iloc[test_idx].values

# %% [markdown]
# #### 4.3 Menormalisasikan data

# %%
def min_max(X):
    X = np.array(X, dtype=float)     
    X_scaled = X.copy()
    
    for i in range(X.shape[1]):
        col = X[:, i]                    
        min_val = col.min()
        max_val = col.max()
        
        if max_val > min_val:
            X_scaled[:, i] = (col - min_val) / (max_val - min_val)
        else:
            X_scaled[:, i] = 0.5         
            
    return X_scaled

X_train_scaled = min_max(X_train)
X_test_scaled  = min_max(X_test)

# %% [markdown]
# #### 4.4 Memastikan ulang nilai train dan tes sesuai

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (920, 8)
# X_test : (231, 8)
# y_train: (920,)
# y_test : (231,)

# %% [markdown]
# #### 4.5 Model KNN

# %%
def predik(X_train, y_train, x_test, k=5):
    x_test = np.array(x_test).ravel()
    distance = []
    for i in range(len(X_train)):
        dist = math.sqrt(np.sum((X_train[i] - x_test) ** 2))
        distance.append((dist, y_train[i]))

    distance.sort(key=lambda x: x[0])
    labels = [label for _, label in distance[:k]]
    return Counter(labels).most_common(1)[0][0]

# %% [markdown]
# *Jaraknya dihitung dengan menggunakan Ecludean Distance, lalu di urutkan dari nilai terkecil ke terbesar, lalu di voting menggunakan Majority vote*

# %% [markdown]
# #### 4.6 Mencari K Terbaik

# %%
accuracies = []
k_range = range(1, 10)

for K in k_range:
    correct = 0
    for i in range(len(X_test_scaled)):
        pred = predik(X_train_scaled, y_train, X_test_scaled[i], k=K)
        if pred == y_test[i]:   
            correct += 1
    acc = correct / len(X_test_scaled)
    accuracies.append(acc)
    print(f"K = {K:2d} | Accuracy = {acc:.4f}")

best_k = k_range[np.argmax(accuracies)]
print(f"\n=== K TERBAIK = {best_k} | Akurasi Tertinggi = {max(accuracies):.4f} ===")
# Out:
# K =  1 | Accuracy = 0.8355
# K =  2 | Accuracy = 0.8355
# K =  3 | Accuracy = 0.8485
# K =  4 | Accuracy = 0.8528
# K =  5 | Accuracy = 0.8701
# K =  6 | Accuracy = 0.8658
# K =  7 | Accuracy = 0.8701
# K =  8 | Accuracy = 0.8658
# K =  9 | Accuracy = 0.8701
#
# === K TERBAIK = 5 | Akurasi Tertinggi = 0.8701 ===

# %% [markdown]
# #### 4.7 Prediksi Model KNN

# %%
y_pred = [] 

for i in range(len(X_test_scaled)):
    pred = predik(X_train_scaled, y_train, X_test_scaled[i], k=best_k)
    y_pred.append(pred)

y_pred = np.array(y_pred)

print(f"Prediksi selesai!")
print(f"Panjang y_test  : {len(y_test)}")
print(f"Panjang y_pred  : {len(y_pred)}")
# Out:
# Prediksi selesai!
# Panjang y_test  : 231
# Panjang y_pred  : 231

# %% [markdown]
# ## 5. Evaluasi

# %% [markdown]
# #### 5.1 Menghitung Confusion Matrix, akurasi, presisi, recall, dan f1

# %%
y_true = y_test.copy()
y_pred = y_pred.copy()

TP = np.sum((y_true == 1) & (y_pred == 1))
TN = np.sum((y_true == 0) & (y_pred == 0))
FP = np.sum((y_true == 0) & (y_pred == 1))
FN = np.sum((y_true == 1) & (y_pred == 0))

conf_matrix = np.array([[TN, FP],
                        [FN, TP]])

accuracy = (TP + TN) / (TP + TN + FP + FN)

precision_apple = TN / (TN + FP) if (TN +FN) > 0 else 0
precision_orange = TP / (TP + FP) if (TP +FP) > 0 else 0

recall_apple = TN / (TN + FN) if (TN + FP) > 0 else 0
recall_orange = TP / (TP + FN) if (TP + FN) > 0 else 0

f1_apple = 2 * precision_apple * recall_apple / (precision_apple + recall_apple) if (precision_apple + recall_apple) > 0 else 0
f1_orange = 2 * precision_orange * recall_orange / (precision_orange + recall_orange) if (precision_orange + recall_orange) > 0 else 0

print(f"Actual Apple {TN:4d}    {FP:4d}\nActual Orange {FN:4d}  {TP:4d}\n")

print(f"Accuracy : {accuracy:.4f} ({accuracy*100:.2f}%)\n")

print(f"Precision Apple : {precision_apple:.4f}\nRecall : {recall_apple:.4f} \nF1 : {f1_apple:.4f}")
print(f"Precision Apple : {precision_orange:.4f}\nRecall : {recall_orange:.4f} \nF1 : {f1_orange:.4f}")
# Out:
# Actual Apple  134       4
# Actual Orange   26    67
#
# Accuracy : 0.8701 (87.01%)
#
# Precision Apple : 0.9710
# Recall : 0.8375
# F1 : 0.8993
# Precision Apple : 0.9437
# Recall : 0.7204
# F1 : 0.8171

# %% [markdown]
# ## 6 Visualisasi

# %%
plt.figure(figsize=(6, 5))

sns.heatmap(conf_matrix, 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=['Apple', 'Orange'],
            yticklabels=['Apple', 'Orange'],
            linewidths=0.5, 
            linecolor='gray',
            cbar=False)

plt.title(f'Confusion Matrix Manual (K = {best_k})\nAccuracy = {accuracy:.4f} ({accuracy*100:.2f}%)', 
          fontsize=14, pad=20)
plt.ylabel('Actual Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.show()
